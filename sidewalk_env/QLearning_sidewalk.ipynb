# %%
import matplotlib.pyplot as plt
import numpy as np
from SideWalkEnv import *
import sys
sys.path.append('..\QLearning_Agent')
from QQL_learner_trainer import GroverQlearner

# %%
env = side_walk_env_with_obstacle(50,15,12,2,0.2)
env.plot_roadmap()

# %%
Elliot = GroverQlearner(env,env_type='local')
hyperp = {'k': 0.2,
          'alpha': 0.1,
          'gamma': 0.7,
          'eps': 0.01,
          'max_epochs': 1000,
          'max_steps': 300}

# set hyperparms
Elliot.set_hyperparams(hyperp)
# TRAIN
steps_in_all_epochs,target_reached_in_all_epochs,_ = Elliot.train()

# plt.plot(steps_in_all_epochs)
# print(Elliot.Q_values)
# Out:
# 1000
# Processing epoch 0 ...
# Updating environment ...
# Processing epoch 50 ...
# Processing epoch 100 ...
# Processing epoch 150 ...
# Processing epoch 200 ...
# Updating environment ...
# Processing epoch 250 ...
# Processing epoch 300 ...
# Processing epoch 350 ...
# Processing epoch 400 ...
# Updating environment ...
# Processing epoch 450 ...
# Processing epoch 500 ...
# Processing epoch 550 ...
# Processing epoch 600 ...
# Updating environment ...
# Processing epoch 650 ...
# Processing epoch 700 ...
# Processing epoch 750 ...
# Processing epoch 800 ...
# Updating environment ...
# Processing epoch 850 ...
# Processing epoch 900 ...
# Processing epoch 950 ...
# Taking step 299/300

# %%
print(Elliot.Q_values)
# Out:
# [[ 8.71162597e+00 -4.61487733e+00  0.00000000e+00  0.00000000e+00]
#  [-7.50434481e+00 -3.45321904e+00  7.04745538e-01  4.59252768e+00]
#  [ 6.66766274e+00 -1.85494101e+00 -6.63868970e+00  4.44072601e-01]
#  [-4.77698021e+00 -6.74739359e-01 -7.88759372e+00  1.58070298e-02]
#  [ 1.65402866e+00 -1.50000000e+00  0.00000000e+00  0.00000000e+00]
#  [-6.39437853e+00 -5.42386742e+00  1.55764328e-02  2.87311766e-01]
#  [ 7.31118975e+00 -1.23820142e+00 -4.51443728e+00  5.16302587e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  4.77108736e-01]
#  [ 7.27925091e+00 -8.86017572e-01  1.65568157e-01 -6.87339990e+00]
#  [-5.05299365e+00 -1.02446508e+00  3.62190355e+00 -4.89905583e+00]
#  [ 8.41413069e+00 -1.70446470e+00 -4.38580484e+00 -4.10215210e+00]
#  [-1.12584405e+01 -2.74856830e+00 -9.78922964e+00 -1.09780836e+01]
#  [ 4.29753185e+00 -7.75361467e+00  4.37787619e-01 -5.32959513e+00]
#  [-9.76126968e+00 -9.73017665e+00  6.96668347e-03 -9.00814734e+00]
#  [ 1.24015208e+00 -2.31582246e+00 -2.47226343e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]

# %%
from QQL_learner_trainer import ClassicalLearner

env = side_walk_env_with_obstacle(50,15,12,2,0.2)
env.plot_roadmap()
Elliot_c = ClassicalLearner(env,env_type='local')
hyperp = {'alpha': 0.1,
          'gamma': 0.8,
          'eps': 0.2,
          'max_epochs': 5000,
          'max_steps': 1000}

# set hyperparms
Elliot_c.set_hyperparams(hyperp)
# TRAIN
steps_in_all_epochs,target_reached_in_all_epochs,_ = Elliot_c.train()

# plt.plot(steps_in_all_epochs)
# print(Elliot_c.Q_values)
# Out:
# 5000
# Processing epoch 0 ...
# Updating environment ...
# Processing epoch 50 ...
# Processing epoch 100 ...
# Processing epoch 150 ...
# Processing epoch 200 ...
# Processing epoch 250 ...
# Processing epoch 300 ...
# Processing epoch 350 ...
# Processing epoch 400 ...
# Processing epoch 450 ...
# Processing epoch 500 ...
# Processing epoch 550 ...
# Processing epoch 600 ...
# Processing epoch 650 ...
# Processing epoch 700 ...
# Processing epoch 750 ...
# Processing epoch 800 ...
# Processing epoch 850 ...
# Processing epoch 900 ...
# Processing epoch 950 ...
# Processing epoch 1000 ...
# Updating environment ...
# Processing epoch 1050 ...
# Processing epoch 1100 ...
# Processing epoch 1150 ...
# Processing epoch 1200 ...
# Processing epoch 1250 ...
# Processing epoch 1300 ...
# Processing epoch 1350 ...
# Processing epoch 1400 ...
# Processing epoch 1450 ...
# Processing epoch 1500 ...
# Processing epoch 1550 ...
# Processing epoch 1600 ...
# Processing epoch 1650 ...
# Processing epoch 1700 ...
# Processing epoch 1750 ...
# Processing epoch 1800 ...
# Processing epoch 1850 ...
# Processing epoch 1900 ...
# Processing epoch 1950 ...
# Processing epoch 2000 ...
# Updating environment ...
# Processing epoch 2050 ...
# Processing epoch 2100 ...
# Processing epoch 2150 ...
# Processing epoch 2200 ...
# Processing epoch 2250 ...
# Processing epoch 2300 ...
# Processing epoch 2350 ...
# Processing epoch 2400 ...
# Processing epoch 2450 ...
# Processing epoch 2500 ...
# Processing epoch 2550 ...
# Processing epoch 2600 ...
# Processing epoch 2650 ...
# Processing epoch 2700 ...
# Processing epoch 2750 ...
# Processing epoch 2800 ...
# Processing epoch 2850 ...
# Processing epoch 2900 ...
# Processing epoch 2950 ...
# Processing epoch 3000 ...
# Updating environment ...
# Processing epoch 3050 ...
# Processing epoch 3100 ...
# Processing epoch 3150 ...
# Processing epoch 3200 ...
# Processing epoch 3250 ...
# Processing epoch 3300 ...
# Processing epoch 3350 ...
# Processing epoch 3400 ...
# Processing epoch 3450 ...
# Processing epoch 3500 ...
# Processing epoch 3550 ...
# Processing epoch 3600 ...
# Processing epoch 3650 ...
# Processing epoch 3700 ...
# Processing epoch 3750 ...
# Processing epoch 3800 ...
# Processing epoch 3850 ...
# Processing epoch 3900 ...
# Processing epoch 3950 ...
# Processing epoch 4000 ...
# Updating environment ...
# Processing epoch 4050 ...
# Processing epoch 4100 ...
# Processing epoch 4150 ...
# Processing epoch 4200 ...
# Processing epoch 4250 ...
# Processing epoch 4300 ...
# Processing epoch 4350 ...
# Processing epoch 4400 ...
# Processing epoch 4450 ...
# Processing epoch 4500 ...
# Processing epoch 4550 ...
# Processing epoch 4600 ...
# Processing epoch 4650 ...
# Processing epoch 4700 ...
# Processing epoch 4750 ...
# Processing epoch 4800 ...
# Processing epoch 4850 ...
# Processing epoch 4900 ...
# Processing epoch 4950 ...
# Taking step 87/10000

# %%
print(Elliot_c.Q_values)
# Out:
# [[13.62526728  4.44334096  9.90499459  9.79329289]
#  [-5.01031582  4.01100589  9.92019062  9.40804265]
#  [13.14461194  4.59629758 -4.27908997 10.49641242]
#  [-6.11569794  4.12758529 -5.3176611  10.74218508]
#  [13.19465483 -4.69892245  9.98467276  9.84477262]
#  [-5.04955086 -4.61702917 10.42886373  9.90288042]
#  [13.76913591 -4.6881251  -5.31366889  9.53495076]
#  [-2.41499238 -1.64412103 -3.06253175 10.26739194]
#  [13.83253644  4.20355395 10.13973658 -5.02640632]
#  [-5.44924732  4.08536599 10.04775686 -5.59873366]
#  [13.48202675  4.53607092 -4.82069638 -4.4573589 ]
#  [-5.05632236  3.21983294 -5.24444132 -6.31375197]
#  [13.40784287 -4.26307144 10.06605968 -2.68103514]
#  [-3.85669541 -4.05025474  6.87342692 -4.20688752]
#  [12.78332969 -4.10631871 -5.26378736 -4.05748479]
#  [-4.66196622 -4.61416617 -4.4299938  -4.61492761]]

# %%
env = side_walk_env_with_obstacle(50,15,12,2,0.15)
trajectory = env.trajectory(Elliot_c.Q_values)
env.plot_roadmap_with_trajectory('avoiding obstacles',trajectory)
# print(trajectory[0])
# Out:
# Done

# %%
print(np.argmax(Elliot_c.Q_values[1,:]))
# Out:
# 2

# %%
env = side_walk_env_with_litter(50,15,12,2,0.2)
env.plot_roadmap()

# %%
from QQL_learner_trainer import ClassicalLearner

env = side_walk_env_with_litter(50,15,12,2,0.2)
env.plot_roadmap()
Elliot_c = ClassicalLearner(env,env_type='local')
hyperp = {'alpha': 0.1,
          'gamma': 0.8,
          'eps': 0.2,
          'max_epochs': 5000,
          'max_steps': 1000}

# set hyperparms
Elliot_c.set_hyperparams(hyperp)
# TRAIN
steps_in_all_epochs,target_reached_in_all_epochs,_ = Elliot_c.train()

# plt.plot(steps_in_all_epochs)
# print(Elliot_c.Q_values)
# Out:
# 5000
# Processing epoch 0 ...
# Updating environment ...
# Processing epoch 50 ...
# Processing epoch 100 ...
# Processing epoch 150 ...
# Processing epoch 200 ...
# Processing epoch 250 ...
# Processing epoch 300 ...
# Processing epoch 350 ...
# Processing epoch 400 ...
# Processing epoch 450 ...
# Processing epoch 500 ...
# Processing epoch 550 ...
# Processing epoch 600 ...
# Processing epoch 650 ...
# Processing epoch 700 ...
# Processing epoch 750 ...
# Processing epoch 800 ...
# Processing epoch 850 ...
# Processing epoch 900 ...
# Processing epoch 950 ...
# Processing epoch 1000 ...
# Updating environment ...
# Processing epoch 1050 ...
# Processing epoch 1100 ...
# Processing epoch 1150 ...
# Processing epoch 1200 ...
# Processing epoch 1250 ...
# Processing epoch 1300 ...
# Processing epoch 1350 ...
# Processing epoch 1400 ...
# Processing epoch 1450 ...
# Processing epoch 1500 ...
# Processing epoch 1550 ...
# Processing epoch 1600 ...
# Processing epoch 1650 ...
# Processing epoch 1700 ...
# Processing epoch 1750 ...
# Processing epoch 1800 ...
# Processing epoch 1850 ...
# Processing epoch 1900 ...
# Processing epoch 1950 ...
# Processing epoch 2000 ...
# Updating environment ...
# Processing epoch 2050 ...
# Processing epoch 2100 ...
# Processing epoch 2150 ...
# Processing epoch 2200 ...
# Processing epoch 2250 ...
# Processing epoch 2300 ...
# Processing epoch 2350 ...
# Processing epoch 2400 ...
# Processing epoch 2450 ...
# Processing epoch 2500 ...
# Processing epoch 2550 ...
# Processing epoch 2600 ...
# Processing epoch 2650 ...
# Processing epoch 2700 ...
# Processing epoch 2750 ...
# Processing epoch 2800 ...
# Processing epoch 2850 ...
# Processing epoch 2900 ...
# Processing epoch 2950 ...
# Processing epoch 3000 ...
# Updating environment ...
# Processing epoch 3050 ...
# Processing epoch 3100 ...
# Processing epoch 3150 ...
# Processing epoch 3200 ...
# Processing epoch 3250 ...
# Processing epoch 3300 ...
# Processing epoch 3350 ...
# Processing epoch 3400 ...
# Processing epoch 3450 ...
# Processing epoch 3500 ...
# Processing epoch 3550 ...
# Processing epoch 3600 ...
# Processing epoch 3650 ...
# Processing epoch 3700 ...
# Processing epoch 3750 ...
# Processing epoch 3800 ...
# Processing epoch 3850 ...
# Processing epoch 3900 ...
# Processing epoch 3950 ...
# Processing epoch 4000 ...
# Updating environment ...
# Processing epoch 4050 ...
# Processing epoch 4100 ...
# Processing epoch 4150 ...
# Processing epoch 4200 ...
# Processing epoch 4250 ...
# Processing epoch 4300 ...
# Processing epoch 4350 ...
# Processing epoch 4400 ...
# Processing epoch 4450 ...
# Processing epoch 4500 ...
# Processing epoch 4550 ...
# Processing epoch 4600 ...
# Processing epoch 4650 ...
# Processing epoch 4700 ...
# Processing epoch 4750 ...
# Processing epoch 4800 ...
# Processing epoch 4850 ...
# Processing epoch 4900 ...
# Processing epoch 4950 ...
# Taking step 527/1000

# %%
print(Elliot_c.Q_values)
# Out:
# [[31.67529929 24.65624484 25.65330453 23.60145137]
#  [40.77199276 28.60622907 36.25282315 35.48619252]
#  [36.02332012 33.55265603 46.73349098 37.09678182]
#  [41.08315865 32.5516224  47.68104089 34.39048295]
#  [34.4822925  34.78619564 34.87064721 36.20671393]
#  [44.32236657 38.73288928 34.01845261 35.47778155]
#  [32.53345179 38.58372462 42.76143529 33.73135792]
#  [47.73531346 33.57451054 35.01479861 33.60852076]
#  [32.6336416  33.60160171 37.74835954 46.7018197 ]
#  [44.64363963 36.06282287 38.30940335 45.90826257]
#  [33.16753467 34.3802941  45.67439474 45.12729027]
#  [40.31288226 26.79166202 38.8728799  44.99610333]
#  [30.83554848 37.44953398 32.24185508 47.70672733]
#  [49.38125103 32.05459574 33.22363665 35.29786255]
#  [28.00472533 32.92678062 34.76019987 34.52561319]
#  [34.7293386  41.59368884 46.69484119 39.32979692]]

# %%
from QQL_learner_trainer import GroverQlearner
env = side_walk_env_with_litter(50,15,12,2,0.3)
Elliot = GroverQlearner(env,env_type='local')
hyperp = {'k': 0.2,
          'alpha': 0.1,
          'gamma': 0.7,
          'eps': 0.01,
          'max_epochs': 500,
          'max_steps': 300}

# set hyperparms
Elliot.set_hyperparams(hyperp)
# TRAIN
steps_in_all_epochs,target_reached_in_all_epochs,_ = Elliot.train()

# plt.plot(steps_in_all_epochs)
# print(Elliot.Q_values)
# Out:
# 500
# Processing epoch 0 ...
# Updating environment ...
# Processing epoch 50 ...
# Processing epoch 100 ...
# Updating environment ...
# Processing epoch 150 ...
# Processing epoch 200 ...
# Updating environment ...
# Processing epoch 250 ...
# Processing epoch 300 ...
# Updating environment ...
# Processing epoch 350 ...
# Processing epoch 400 ...
# Updating environment ...
# Processing epoch 450 ...
# Taking step 299/300

# %%
print(Elliot.Q_values)
# Out:
# [[ 1.08052622e+01 -8.88375491e+00 -3.32062624e-02  0.00000000e+00]
#  [ 3.56384305e+01 -1.16139995e+00  0.00000000e+00  5.15584967e-01]
#  [ 0.00000000e+00  1.79859206e-01  0.00000000e+00  1.83026350e+00]
#  [ 4.34844135e+01 -2.94507787e-01  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.48617075e-02  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 2.55708264e+01  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 4.15375775e+01  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  2.76158065e+01]
#  [ 0.00000000e+00 -5.00000000e-01  0.00000000e+00  4.47548822e+01]
#  [ 0.00000000e+00  0.00000000e+00  4.72293487e+01  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  1.25696625e+01  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]

# %%
env = side_walk_env_with_litter(50,15,12,2,0.3)
env.plot_roadmap()
