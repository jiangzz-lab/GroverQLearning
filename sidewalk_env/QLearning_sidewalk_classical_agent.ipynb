# %%
import matplotlib.pyplot as plt
import numpy as np
from SideWalkEnv import *
import sys
sys.path.append('..\QLearning_Agent')

# %%
env_with_obstacle_train = side_walk_env_with_obstacle(50,15,12,2,0.2)
env_with_obstacle_train.plot_roadmap()

# %%
from QQL_learner_trainer import ClassicalLearner

# env = side_walk_env_with_obstacle(50,15,12,2,0.2)
# env.plot_roadmap()
Elliot_obstacle_cl = ClassicalLearner(env_with_obstacle_train,env_type='local')
hyperp = {'alpha': 0.1,
          'gamma': 0.8,
          'eps': 0.2,
          'max_epochs': 6000,
          'max_steps': 1000}

# set hyperparms
Elliot_obstacle_cl.set_hyperparams(hyperp)
# TRAIN
steps_in_all_epochs,target_reached_in_all_epochs,_ = Elliot_obstacle_cl.train()

# plt.plot(steps_in_all_epochs)
print(Elliot_obstacle_cl.Q_values)
# Out:
# 6000
# Processing epoch 0 ...
# Updating environment ...
# Processing epoch 50 ...
# Processing epoch 100 ...
# Processing epoch 150 ...
# Processing epoch 200 ...
# Processing epoch 250 ...
# Processing epoch 300 ...
# Processing epoch 350 ...
# Processing epoch 400 ...
# Processing epoch 450 ...
# Processing epoch 500 ...
# Processing epoch 550 ...
# Processing epoch 600 ...
# Processing epoch 650 ...
# Processing epoch 700 ...
# Processing epoch 750 ...
# Processing epoch 800 ...
# Processing epoch 850 ...
# Processing epoch 900 ...
# Processing epoch 950 ...
# Processing epoch 1000 ...
# Processing epoch 1050 ...
# Processing epoch 1100 ...
# Processing epoch 1150 ...
# Processing epoch 1200 ...
# Updating environment ...
# Processing epoch 1250 ...
# Processing epoch 1300 ...
# Processing epoch 1350 ...
# Processing epoch 1400 ...
# Processing epoch 1450 ...
# Processing epoch 1500 ...
# Processing epoch 1550 ...
# Processing epoch 1600 ...
# Processing epoch 1650 ...
# Processing epoch 1700 ...
# Processing epoch 1750 ...
# Processing epoch 1800 ...
# Processing epoch 1850 ...
# Processing epoch 1900 ...
# Processing epoch 1950 ...
# Processing epoch 2000 ...
# Processing epoch 2050 ...
# Processing epoch 2100 ...
# Processing epoch 2150 ...
# Processing epoch 2200 ...
# Processing epoch 2250 ...
# Processing epoch 2300 ...
# Processing epoch 2350 ...
# Processing epoch 2400 ...
# Updating environment ...
# Processing epoch 2450 ...
# Processing epoch 2500 ...
# Processing epoch 2550 ...
# Processing epoch 2600 ...
# Processing epoch 2650 ...
# Processing epoch 2700 ...
# Processing epoch 2750 ...
# Processing epoch 2800 ...
# Processing epoch 2850 ...
# Processing epoch 2900 ...
# Processing epoch 2950 ...
# Processing epoch 3000 ...
# Processing epoch 3050 ...
# Processing epoch 3100 ...
# Processing epoch 3150 ...
# Processing epoch 3200 ...
# Processing epoch 3250 ...
# Processing epoch 3300 ...
# Processing epoch 3350 ...
# Processing epoch 3400 ...
# Processing epoch 3450 ...
# Processing epoch 3500 ...
# Processing epoch 3550 ...
# Processing epoch 3600 ...
# Updating environment ...
# Processing epoch 3650 ...
# Processing epoch 3700 ...
# Processing epoch 3750 ...
# Processing epoch 3800 ...
# Processing epoch 3850 ...
# Processing epoch 3900 ...
# Processing epoch 3950 ...
# Processing epoch 4000 ...
# Processing epoch 4050 ...
# Processing epoch 4100 ...
# Processing epoch 4150 ...
# Processing epoch 4200 ...
# Processing epoch 4250 ...
# Processing epoch 4300 ...
# Processing epoch 4350 ...
# Processing epoch 4400 ...
# Processing epoch 4450 ...
# Processing epoch 4500 ...
# Processing epoch 4550 ...
# Processing epoch 4600 ...
# Processing epoch 4650 ...
# Processing epoch 4700 ...
# Processing epoch 4750 ...
# Processing epoch 4800 ...
# Updating environment ...
# Processing epoch 4850 ...
# Processing epoch 4900 ...
# Processing epoch 4950 ...
# Processing epoch 5000 ...
# Processing epoch 5050 ...
# Processing epoch 5100 ...
# Processing epoch 5150 ...
# Processing epoch 5200 ...
# Processing epoch 5250 ...
# Processing epoch 5300 ...
# Processing epoch 5350 ...
# Processing epoch 5400 ...
# Processing epoch 5450 ...
# Processing epoch 5500 ...
# Processing epoch 5550 ...
# Processing epoch 5600 ...
# Processing epoch 5650 ...
# Processing epoch 5700 ...
# Processing epoch 5750 ...
# Processing epoch 5800 ...
# Processing epoch 5850 ...
# Processing epoch 5900 ...
# Processing epoch 5950 ...
# [[33.84966132 27.16323777 27.5062401  27.89839094]
#  [23.03818124 26.02220384 26.3589539  27.20976694]
#  [34.5457969  27.14754055 22.13804236 27.85757263]
#  [22.3255475  25.56049557 23.04008686 28.15532879]
#  [32.32755829 23.31644072 28.19401949 27.52311345]
#  [22.80658163 22.45798648 26.1561362  29.53148362]
#  [31.25395123 22.84580989 21.02088839 28.11978341]
#  [22.45810038 22.51728938 21.83156877 27.3842759 ]
#  [33.55127296 27.47786236 26.4438799  20.84394008]
#  [21.69784862 24.94544718 28.66003821 23.22791283]
#  [33.02870785 27.22871843 22.04411934 21.9523103 ]
#  [20.97086393 25.45365687 22.7959308  22.68575213]
#  [32.69902746 22.97025689 29.22924221 21.28225083]
#  [22.92858428 22.9780695  24.74209555 19.54078693]
#  [35.11302622 23.16497151 19.09030396 22.6546998 ]
#  [ 0.          0.          0.          0.        ]]

# %%
env_with_obstacle_test = side_walk_env_with_obstacle(50,15,12,2,0.15)
trajectory_obstacle = env_with_obstacle_test.trajectory(Elliot_obstacle_cl.Q_values)
env_with_obstacle_test.plot_roadmap_with_trajectory('avoiding obstacles_Classical agent',trajectory_obstacle)
# print(trajectory[0])
# Out:
# Done

# %%
env_with_litter_train = side_walk_env_with_litter(50,15,12,2,0.2)
env_with_litter_train.plot_roadmap()

# %%
from QQL_learner_trainer import ClassicalLearner

Elliot_litter_cl = ClassicalLearner(env_with_litter_train,env_type='local')
hyperp = {'alpha': 0.1,
          'gamma': 0.8,
          'eps': 0.2,
          'max_epochs': 5000,
          'max_steps': 1000}

# set hyperparms
Elliot_litter_cl.set_hyperparams(hyperp)
# TRAIN
steps_in_all_epochs,target_reached_in_all_epochs,_ = Elliot_litter_cl.train()


print(Elliot_litter_cl.Q_values)
# Out:
# 5000
# Processing epoch 0 ...
# Updating environment ...
# Processing epoch 50 ...
# Processing epoch 100 ...
# Processing epoch 150 ...
# Processing epoch 200 ...
# Processing epoch 250 ...
# Processing epoch 300 ...
# Processing epoch 350 ...
# Processing epoch 400 ...
# Processing epoch 450 ...
# Processing epoch 500 ...
# Processing epoch 550 ...
# Processing epoch 600 ...
# Processing epoch 650 ...
# Processing epoch 700 ...
# Processing epoch 750 ...
# Processing epoch 800 ...
# Processing epoch 850 ...
# Processing epoch 900 ...
# Processing epoch 950 ...
# Processing epoch 1000 ...
# Updating environment ...
# Processing epoch 1050 ...
# Processing epoch 1100 ...
# Processing epoch 1150 ...
# Processing epoch 1200 ...
# Processing epoch 1250 ...
# Processing epoch 1300 ...
# Processing epoch 1350 ...
# Processing epoch 1400 ...
# Processing epoch 1450 ...
# Processing epoch 1500 ...
# Processing epoch 1550 ...
# Processing epoch 1600 ...
# Processing epoch 1650 ...
# Processing epoch 1700 ...
# Processing epoch 1750 ...
# Processing epoch 1800 ...
# Processing epoch 1850 ...
# Processing epoch 1900 ...
# Processing epoch 1950 ...
# Processing epoch 2000 ...
# Updating environment ...
# Processing epoch 2050 ...
# Processing epoch 2100 ...
# Processing epoch 2150 ...
# Processing epoch 2200 ...
# Processing epoch 2250 ...
# Processing epoch 2300 ...
# Processing epoch 2350 ...
# Processing epoch 2400 ...
# Processing epoch 2450 ...
# Processing epoch 2500 ...
# Processing epoch 2550 ...
# Processing epoch 2600 ...
# Processing epoch 2650 ...
# Processing epoch 2700 ...
# Processing epoch 2750 ...
# Processing epoch 2800 ...
# Processing epoch 2850 ...
# Processing epoch 2900 ...
# Processing epoch 2950 ...
# Processing epoch 3000 ...
# Updating environment ...
# Processing epoch 3050 ...
# Processing epoch 3100 ...
# Processing epoch 3150 ...
# Processing epoch 3200 ...
# Processing epoch 3250 ...
# Processing epoch 3300 ...
# Processing epoch 3350 ...
# Processing epoch 3400 ...
# Processing epoch 3450 ...
# Processing epoch 3500 ...
# Processing epoch 3550 ...
# Processing epoch 3600 ...
# Processing epoch 3650 ...
# Processing epoch 3700 ...
# Processing epoch 3750 ...
# Processing epoch 3800 ...
# Processing epoch 3850 ...
# Processing epoch 3900 ...
# Processing epoch 3950 ...
# Processing epoch 4000 ...
# Updating environment ...
# Processing epoch 4050 ...
# Processing epoch 4100 ...
# Processing epoch 4150 ...
# Processing epoch 4200 ...
# Processing epoch 4250 ...
# Processing epoch 4300 ...
# Processing epoch 4350 ...
# Processing epoch 4400 ...
# Processing epoch 4450 ...
# Processing epoch 4500 ...
# Processing epoch 4550 ...
# Processing epoch 4600 ...
# Processing epoch 4650 ...
# Processing epoch 4700 ...
# Processing epoch 4750 ...
# Processing epoch 4800 ...
# Processing epoch 4850 ...
# Processing epoch 4900 ...
# Processing epoch 4950 ...
# [[40.85910837 27.90972684 35.06129588 36.8016609 ]
#  [51.82185671 29.63117392 34.67565614 35.33074898]
#  [42.4919651  29.06609617 49.73637833 37.08769787]
#  [50.77698201 29.18114581 49.16367002 35.27907575]
#  [39.16386315 29.18669248 35.44386544 36.05293365]
#  [47.85947074 28.79883428 35.58330341 34.18842796]
#  [41.86464736 19.98603899 48.37854402 27.0949815 ]
#  [50.3954396   5.82912364  5.04798673  3.51313505]
#  [39.01529265 27.80155137 34.53516077 50.31470161]
#  [51.62070821 28.38253203 34.82200206 50.68111899]
#  [39.27146099 28.46034642 48.63079955 49.25241557]
#  [49.05360169 30.38116738 49.47026845 48.82686596]
#  [40.50545063 14.55222044 25.9507828  33.12192419]
#  [46.37620551  8.57729824  0.         12.80815572]
#  [ 3.97863806  0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]

# %%
env_with_litter_test = side_walk_env_with_litter(50,15,12,2,0.15)
trajectory_litter = env_with_litter_test.trajectory(Elliot_litter_cl.Q_values)
env_with_litter_test.plot_roadmap_with_trajectory('picking up litters_Classical agent',trajectory_litter)
# Out:
# Done

# %%
print(Elliot_litter_cl.Q_values)
# Out:
# [[40.85910837 27.90972684 35.06129588 36.8016609 ]
#  [51.82185671 29.63117392 34.67565614 35.33074898]
#  [42.4919651  29.06609617 49.73637833 37.08769787]
#  [50.77698201 29.18114581 49.16367002 35.27907575]
#  [39.16386315 29.18669248 35.44386544 36.05293365]
#  [47.85947074 28.79883428 35.58330341 34.18842796]
#  [41.86464736 19.98603899 48.37854402 27.0949815 ]
#  [50.3954396   5.82912364  5.04798673  3.51313505]
#  [39.01529265 27.80155137 34.53516077 50.31470161]
#  [51.62070821 28.38253203 34.82200206 50.68111899]
#  [39.27146099 28.46034642 48.63079955 49.25241557]
#  [49.05360169 30.38116738 49.47026845 48.82686596]
#  [40.50545063 14.55222044 25.9507828  33.12192419]
#  [46.37620551  8.57729824  0.         12.80815572]
#  [ 3.97863806  0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]]
