# %%
import numpy as np
from SideWalkEnv import side_walk_env,side_walk_env_with_litter,side_walk_env_with_obstacle

# %%
env = side_walk_env()
env.plot_roadmap()
env1 = side_walk_env_with_obstacle()
env1.plot_roadmap()
env2 = side_walk_env_with_litter()
env2.plot_roadmap()
