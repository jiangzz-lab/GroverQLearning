# %%
import matplotlib.pyplot as plt
import numpy as np
from SideWalkEnv import *
import sys
sys.path.append('..\QLearning_Agent')
from QQL_learner_trainer import GroverQlearner

# %%
env = side_walk_env_with_obstacle(50,15,13,3,0.1)
env.plot_roadmap()

# %%
Elliot = GroverQlearner(env)
hyperp = {'k': 0.1,
          'alpha': 0.1,
          'gamma': 0.99,
          'eps': 0.01,
          'max_epochs': 300,
          'max_steps': 100}

# set hyperparms
Elliot.set_hyperparams(hyperp)
# TRAIN
steps_in_all_epochs,target_reached_in_all_epochs,_ = Elliot.train()

plt.plot(steps_in_all_epochs)
# Out:
# 300
# Processing epoch 0 ...
# Processing epoch 10 ...
# Processing epoch 20 ...
# Processing epoch 30 ...
# Processing epoch 40 ...
# Processing epoch 50 ...
# Processing epoch 60 ...
# Processing epoch 70 ...
# Taking step 0/100
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [3], line 12
#      10 Elliot.set_hyperparams(hyperp)
#      11 # TRAIN
# ---> 12 steps_in_all_epochs,target_reached_in_all_epochs,_ = Elliot.train()
#      14 plt.plot(steps_in_all_epochs)
#
# File c:\Users\gq199\GroverQLearning\GroverQLearning\sidewalk_env\..\QLearning_Agent\QQL_learner_trainer.py:108, in RL_Qlearning_trainer.train(self)
#     106 print('Taking step {0}/{1}'.format(step, optimal_steps), end='\r')
#     107 self.action = self._take_action() # take an action
# --> 108 new_state, reward, _, done, _ = self.env.step(self.action) # step to the new state
#     109 if new_state == self.state:
#     110     reward -= 10 # take less reward if stay in the same state
#
# File c:\Users\gq199\GroverQLearning\GroverQLearning\sidewalk_env\SideWalkEnv.py:91, in side_walk_env_with_obstacle.step(self, action)
#      89 if action == 0: # move left
#      90     next_position = [current_position[0], current_position[1] - 1]
# ---> 91     self.state = self.position_to_state(next_position,1)
#      92     self.current_position = next_position
#      93     if self.roadmap[next_position[0], next_position[1]] == 1:
#
# File c:\Users\gq199\GroverQLearning\GroverQLearning\sidewalk_env\SideWalkEnv.py:50, in side_walk_env.position_to_state(self, current_position, ob_bo)
#      47 down = current_position + np.array([-1,0])
#      48 up = current_position + np.array([1,0])
#      49 state = (2**0 * int(self.roadmap[up[0], up[1]]==ob_bo) + 2**1 * int(self.roadmap[down[0], down[1]]==ob_bo)
# ---> 50     + 2**2 * int(self.roadmap[left[0], left[1]]==ob_bo) + 2**3 * int(self.roadmap[right[0], right[1]]==ob_bo))
#      51 return state
#
# IndexError: index -16 is out of bounds for axis 1 with size 15
