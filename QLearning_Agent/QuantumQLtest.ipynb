# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
from QQL_learner_trainer import GroverQlearner
# test
# choose env
envtest = gym.make("FrozenLake-v1", is_slippery=False, render_mode="ansi")
# init learner
Elliot = GroverQlearner(envtest)
# good hyperparms (hand-tuned)
hyperp = {'k': 0.1,
          'alpha': 0.1,
          'gamma': 0.99,
          'eps': 0.01,
          'max_epochs': 3000,
          'max_steps': 15}
# set hyperparms
Elliot.set_hyperparams(hyperp)

# TRAIN
steps_in_all_epochs,target_reached_in_all_epochs,_ = Elliot.train()

plt.plot(steps_in_all_epochs)
# Out:
# 3000
# Processing epoch 0 ...
# Processing epoch 10 ...
# Processing epoch 20 ...
# Processing epoch 30 ...
# Processing epoch 40 ...
# Processing epoch 50 ...
# Processing epoch 60 ...
# Processing epoch 70 ...
# Processing epoch 80 ...
# Processing epoch 90 ...
# Processing epoch 100 ...
# Processing epoch 110 ...
# Processing epoch 120 ...
# Processing epoch 130 ...
# Processing epoch 140 ...
# Processing epoch 150 ...
# Processing epoch 160 ...
# Processing epoch 170 ...
# Processing epoch 180 ...
# Processing epoch 190 ...
# Processing epoch 200 ...
# Processing epoch 210 ...
# Processing epoch 220 ...
# Processing epoch 230 ...
# Processing epoch 240 ...
# Processing epoch 250 ...
# Processing epoch 260 ...
# Processing epoch 270 ...
# Processing epoch 280 ...
# Processing epoch 290 ...
# Processing epoch 300 ...
# Processing epoch 310 ...
# Processing epoch 320 ...
# Processing epoch 330 ...
# Processing epoch 340 ...
# Processing epoch 350 ...
# Processing epoch 360 ...
# ...

# %%
print(steps_in_all_epochs[-1])
plt.scatter(range(len(target_reached_in_all_epochs)),target_reached_in_all_epochs)
# Out:
# 7

# %%
print(Elliot.Q_values)
print(np.max(Elliot.Q_values, axis=1).reshape((4, 4)))
# Out:
# [[-4.97089838e+02  3.91669142e+03 -9.71842101e+01 -4.82802114e+02]
#  [-9.23825019e+01 -8.63272595e+01 -2.78689178e+01 -1.68140782e+02]
#  [-2.75132552e+01 -1.46484278e+01 -8.84056963e+00 -6.10861223e+01]
#  [-4.52549812e+00 -5.35811259e+00 -1.48954536e+01 -1.39093630e+01]
#  [-1.49627724e+02  4.00780340e+03 -8.92473381e+01 -7.48076913e+01]
#  [-1.09576457e+02 -6.76388351e+01 -1.01522429e+02 -9.06702885e+01]
#  [-4.95166143e+01  1.73821487e+01 -5.81892679e+00 -6.14001648e+00]
#  [-1.29222853e+01 -5.98501999e+00 -7.97205593e+00 -7.97205593e+00]
#  [-4.30671093e+01 -1.14789371e+01  4.09978517e+03 -1.54446740e+01]
#  [-2.53515094e+00 -6.73984819e-01  4.19264557e+03 -3.42758894e+01]
#  [-6.62499985e-01  4.28639350e+03 -4.98610000e-01 -2.22907531e+00]
#  [ 0.00000000e+00 -2.99700100e+00 -1.00000000e+00 -1.00000000e+00]
#  [-1.48954536e+01 -1.58805582e+01 -9.95511979e+00 -1.09451647e+01]
#  [-3.78100000e-01 -1.99900000e+00  2.50100000e+00 -1.42491889e-01]
# ...

# %%
print(envtest.render())
# Out:
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
